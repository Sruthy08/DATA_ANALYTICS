# %% [markdown]
# <a href="https://colab.research.google.com/github/Sruthy08/DATA_ANALYTICS/blob/main/NPL_DATASET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **NPL_DATASET**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Upload Dataset**

# %%
NPL=pd.read_csv('NPL_DATASET.csv')

# %% [markdown]
# **NPL_DATASET**

# %%
NPL
# Out:
#                Team 1             Team 2        Toss_Winner Toss_Decision  \
# 0    Biratnagar Kings     Janakpur Bolts     Janakpur Bolts         field
# 1   Kathmandu Gurkhas     Chitwan Rhinos     Chitwan Rhinos         field
# 2        Karnali Yaks     Janakpur Bolts       Karnali Yaks           bat
# 3       Sudur Paschim   Biratnagar Kings   Biratnagar Kings         field
# 4      Chitwan Rhinos   Pokhara Avengers   Pokhara Avengers         field
# 5        Karnali Yaks  Kathmandu Gurkhas  Kathmandu Gurkhas         field
# 6       Lumbini Lions   Biratnagar Kings   Biratnagar Kings         field
# 7    Pokhara Avengers     Janakpur Bolts     Janakpur Bolts         field
# 8       Sudur Paschim  Kathmandu Gurkhas  Kathmandu Gurkhas         field
# 9      Chitwan Rhinos       Karnali Yaks       Karnali Yaks         field
# 10      Lumbini Lions   Pokhara Avengers      Lumbini Lions           bat
# 11      Sudur Paschim      Lumbini Lions      Lumbini Lions         field
# ...

# %% [markdown]
# **DATASET ANALYSIS**

# %%
NPL.drop(0)
# Out:
#                Team 1             Team 2        Toss_Winner Toss_Decision  \
# 1   Kathmandu Gurkhas     Chitwan Rhinos     Chitwan Rhinos         field
# 2        Karnali Yaks     Janakpur Bolts       Karnali Yaks           bat
# 3       Sudur Paschim   Biratnagar Kings   Biratnagar Kings         field
# 4      Chitwan Rhinos   Pokhara Avengers   Pokhara Avengers         field
# 5        Karnali Yaks  Kathmandu Gurkhas  Kathmandu Gurkhas         field
# 6       Lumbini Lions   Biratnagar Kings   Biratnagar Kings         field
# 7    Pokhara Avengers     Janakpur Bolts     Janakpur Bolts         field
# 8       Sudur Paschim  Kathmandu Gurkhas  Kathmandu Gurkhas         field
# 9      Chitwan Rhinos       Karnali Yaks       Karnali Yaks         field
# 10      Lumbini Lions   Pokhara Avengers      Lumbini Lions           bat
# 11      Sudur Paschim      Lumbini Lions      Lumbini Lions         field
# 12       Karnali Yaks   Biratnagar Kings   Biratnagar Kings         field
# ...

# %%
NPL.columns
# Out:
# Index(['Team 1', 'Team 2', 'Toss_Winner', 'Toss_Decision', 'Season',
#        'Player Of The Match', 'Match_Day', 'Umpires', 'Match Info',
#        'First_Team_Performance', 'Target_Runs', 'Wic_lost_by_1st_team',
#        'Second_Team_Performance', 'Run_Scored_By_2nd_Team',
#        'Wic_Lost_by_2nd_Team', 'Run_Rate_Team_1', 'Run_Rate_Team_2',
#        'Winner_Team', 'won_by_margin', 'Powerplay1', 'Powerplay2',
#        'Extras_of_inning_1', ' Extras_of_inning_2'],
#       dtype='object')

# %%
NPL.shape
# Out:
# (32, 23)

# %%
NPL.size
# Out:
# 736

# %%
NPL.ndim
# Out:
# 2

# %%
NPL.describe
# Out:
# <bound method NDFrame.describe of                Team 1             Team 2        Toss_Winner Toss_Decision  \
# 0    Biratnagar Kings     Janakpur Bolts     Janakpur Bolts         field
# 1   Kathmandu Gurkhas     Chitwan Rhinos     Chitwan Rhinos         field
# 2        Karnali Yaks     Janakpur Bolts       Karnali Yaks           bat
# 3       Sudur Paschim   Biratnagar Kings   Biratnagar Kings         field
# 4      Chitwan Rhinos   Pokhara Avengers   Pokhara Avengers         field
# 5        Karnali Yaks  Kathmandu Gurkhas  Kathmandu Gurkhas         field
# 6       Lumbini Lions   Biratnagar Kings   Biratnagar Kings         field
# 7    Pokhara Avengers     Janakpur Bolts     Janakpur Bolts         field
# 8       Sudur Paschim  Kathmandu Gurkhas  Kathmandu Gurkhas         field
# 9      Chitwan Rhinos       Karnali Yaks       Karnali Yaks         field
# 10      Lumbini Lions   Pokhara Avengers      Lumbini Lions           bat
# ...

# %%
NPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Team 1                   32 non-null     object
#  1   Team 2                   32 non-null     object
#  2   Toss_Winner              32 non-null     object
#  3   Toss_Decision            32 non-null     object
#  4   Season                   32 non-null     object
#  5   Player Of The Match      32 non-null     object
#  6   Match_Day                32 non-null     object
#  7   Umpires                  32 non-null     object
#  8   Match Info               32 non-null     object
#  9   First_Team_Performance   32 non-null     object
#  10  Target_Runs              32 non-null     int64
#  11  Wic_lost_by_1st_team     32 non-null     int64
#  12  Second_Team_Performance  32 non-null     object
#  13  Run_Scored_By_2nd_Team   32 non-null     int64
# ...

# %%
NPL.head()
# Out:
#               Team 1            Team 2       Toss_Winner Toss_Decision  \
# 0   Biratnagar Kings    Janakpur Bolts    Janakpur Bolts         field
# 1  Kathmandu Gurkhas    Chitwan Rhinos    Chitwan Rhinos         field
# 2       Karnali Yaks    Janakpur Bolts      Karnali Yaks           bat
# 3      Sudur Paschim  Biratnagar Kings  Biratnagar Kings         field
# 4     Chitwan Rhinos  Pokhara Avengers  Pokhara Avengers         field
#
#     Season   Player Of The Match  Match_Day  \
# 0  2024/25       Lahiru Milantha  30-Nov-24
# 1  2024/25         Sohail Tanvir   2-Dec-24
# 2  2024/25              Anil Sah   2-Dec-24
# 3  2024/25  Dipendra Singh Airee   3-Dec-24
# 4  2024/25          Rijan Dhakal   3-Dec-24
#
#                                      Umpires  \
# 0            ['Durga Subedi', 'Vinay Kumar']
# 1           ['Buddhi Pradhan', 'Himal Giri']
# 2  ['Bismillah Jan Shinwari', 'Rashid Riaz']
# 3             ['Durga Subedi', 'Himal Giri']
# ...

# %%
NPL.tail()
# Out:
#             Team 1          Team 2     Toss_Winner Toss_Decision   Season  \
# 27    Karnali Yaks   Sudur Paschim   Sudur Paschim         field  2024/25
# 28    Karnali Yaks  Chitwan Rhinos  Chitwan Rhinos         field  2024/25
# 29  Janakpur Bolts   Sudur Paschim  Janakpur Bolts           bat  2024/25
# 30    Karnali Yaks  Janakpur Bolts  Janakpur Bolts         field  2024/25
# 31   Sudur Paschim  Janakpur Bolts   Sudur Paschim           bat  2024/25
#
#      Player Of The Match  Match_Day  \
# 27  Dipendra Singh Airee  16-Dec-24
# 28       Chadwick Walton  18-Dec-24
# 29        Binod Bhandari  18-Dec-24
# 30         James Neesham  19-Dec-24
# 31       Lahiru Milantha  21-Dec-24
#
#                                          Umpires  \
# 27               ['Himal Giri', 'Sanjay Gurung']
# 28              ['Rashid Riaz', 'Sanjay Gurung']
# 29  ['Bismillah Jan Shinwari', 'Buddhi Pradhan']
# 30               ['Durga Subedi', 'Vinay Kumar']
# ...

# %%
NPL.isnull().sum()
# Out:
# Team 1                     0
# Team 2                     0
# Toss_Winner                0
# Toss_Decision              0
# Season                     0
# Player Of The Match        0
# Match_Day                  0
# Umpires                    0
# Match Info                 0
# First_Team_Performance     0
# Target_Runs                0
# Wic_lost_by_1st_team       0
# Second_Team_Performance    0
# Run_Scored_By_2nd_Team     0
# Wic_Lost_by_2nd_Team       0
# Run_Rate_Team_1            0
# Run_Rate_Team_2            0
# Winner_Team                0
# won_by_margin              0
# Powerplay1                 0
# Powerplay2                 0
# Extras_of_inning_1         0
#  Extras_of_inning_2        0
# dtype: int64

# %%
NPL['Toss_Winner'].unique()
# Out:
# array(['Janakpur Bolts', 'Chitwan Rhinos', 'Karnali Yaks',
#        'Biratnagar Kings', 'Pokhara Avengers', 'Kathmandu Gurkhas',
#        'Lumbini Lions', 'Sudur Paschim'], dtype=object)

# %%
print(NPL['Toss_Winner'].value_counts())
# Out:
# Toss_Winner
# Kathmandu Gurkhas    6
# Janakpur Bolts       5
# Biratnagar Kings     5
# Chitwan Rhinos       5
# Lumbini Lions        4
# Pokhara Avengers     3
# Karnali Yaks         2
# Sudur Paschim        2
# Name: count, dtype: int64

# %%
print(NPL['Toss_Decision'].value_counts())
# Out:
# Toss_Decision
# field    21
# bat      11
# Name: count, dtype: int64

# %%
print(NPL['Team 1'].value_counts())
# Out:
# Team 1
# Karnali Yaks         7
# Sudur Paschim        6
# Biratnagar Kings     4
# Chitwan Rhinos       4
# Kathmandu Gurkhas    3
# Lumbini Lions        3
# Pokhara Avengers     3
# Janakpur Bolts       2
# Name: count, dtype: int64

# %%
print(NPL['Team 2'].value_counts())
# Out:
# Team 2
# Janakpur Bolts       8
# Chitwan Rhinos       4
# Pokhara Avengers     4
# Kathmandu Gurkhas    4
# Lumbini Lions        4
# Biratnagar Kings     3
# Sudur Paschim        3
# Karnali Yaks         2
# Name: count, dtype: int64

# %%
print(NPL['Run_Rate_Team_1'].value_counts())
# Out:
# Run_Rate_Team_1
# 8.35    2
# 6.90    2
# 6.95    2
# 5.55    1
# 7.05    1
# 8.05    1
# 9.10    1
# 9.55    1
# 7.45    1
# 6.50    1
# 8.50    1
# 9.35    1
# 6.68    1
# 6.65    1
# 6.80    1
# 6.24    1
# 8.20    1
# 6.15    1
# 5.32    1
# 5.17    1
# 6.40    1
# 9.05    1
# 9.00    1
# 5.89    1
# 7.65    1
# 5.05    1
# 8.75    1
# 5.90    1
# 9.20    1
# Name: count, dtype: int64

# %%
print(NPL['Run_Rate_Team_2'].value_counts())
# Out:
# Run_Rate_Team_2
# 8.45     1
# 6.64     1
# 9.36     1
# 5.69     1
# 5.55     1
# 7.84     1
# 9.73     1
# 8.33     1
# 5.93     1
# 6.65     1
# 10.45    1
# 7.10     1
# 6.30     1
# 6.75     1
# 7.14     1
# 6.70     1
# 7.06     1
# 4.19     1
# 4.39     1
# 6.95     1
# 6.56     1
# 6.15     1
# 6.50     1
# 10.02    1
# 8.22     1
# 6.60     1
# 7.52     1
# 6.84     1
# 7.70     1
# 7.62     1
# 6.26     1
# 9.56     1
# Name: count, dtype: int64

# %%
print(NPL['Wic_Lost_by_2nd_Team'].value_counts())
# Out:
# Wic_Lost_by_2nd_Team
# 10    8
# 8     5
# 5     3
# 2     3
# 9     3
# 4     3
# 3     2
# 7     2
# 6     2
# 0     1
# Name: count, dtype: int64

# %% [markdown]
# **Heatmap Analysis**

# %%
NPL['First_Team_Performance'].hist()
# Out:
# <Axes: >

# %%
sns.heatmap(NPL.corr(numeric_only=True),annot=True,cmap='plasma')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# **Scatterplot Team Performance Analysis**

# %%
sns.scatterplot(x=NPL['Run_Scored_By_2nd_Team'],
                y=NPL['First_Team_Performance'])
# Out:
# <Axes: xlabel='Run_Scored_By_2nd_Team', ylabel='First_Team_Performance'>

# %%
sns.scatterplot(x=NPL['Run_Rate_Team_1'],
                y=NPL['Run_Rate_Team_2'])
# Out:
# <Axes: xlabel='Run_Rate_Team_1', ylabel='Run_Rate_Team_2'>

# %%
sns.countplot(NPL['Toss_Decision'])
# Out:
# <Axes: xlabel='count', ylabel='Toss_Decision'>

# %%
x=NPL[['First_Team_Performance','Run_Scored_By_2nd_Team','Run_Rate_Team_1','Run_Rate_Team_2']]
y=NPL['Wic_Lost_by_2nd_Team']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model=LogisticRegression()
